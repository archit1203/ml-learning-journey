# %% [markdown]
# # Python Basics Walk Along

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Data Types

# %%
print(type(1+2))
print(type(2.5))
print(type(True))
print(type(False))
print(type("1+2"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>
# <class 'str'>
